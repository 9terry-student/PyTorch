# %% [markdown]
# <a href="https://colab.research.google.com/github/9terry-student/PyTorch/blob/main/Linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch.nn.functional as F
import torch.nn as nn
import torch
import torch.optim as optim

class MultivariateLinearRegressionModel(nn.Module):
  def __init__(self):
    super().__init__()
    self.linear=nn.Linear(3,1)
  def forward(self,x):
    return self.linear(x)

x_train=torch.FloatTensor([[73,80,75],[93,88,93],[89,91,90],[96,98,100],[73,66,70]])
y_train=torch.FloatTensor([[152],[185],[180],[196],[142]])

model=MultivariateLinearRegressionModel()
optimizer=optim.SGD(model.parameters(),lr=1e-5)

epochs=20
for epoch in range(epochs+1):
  h=model(x_train)
  cost=F.mse_loss(h,y_train)

  optimizer.zero_grad()
  cost.backward()
  optimizer.step()

  print('Epoch {:4d}/{} hypo  :{} cost : {:.6f}'.format(epoch, epochs,h.squeeze().detach(),cost.item()))
# Out:
# Epoch    0/20 hypo  :tensor([12.6852, 17.5911, 16.1050, 18.1941, 13.3830]) cost : 24490.642578
# Epoch    1/20 hypo  :tensor([73.8005, 91.0474, 88.4827, 97.0116, 69.4118]) cost : 7677.081055
# Epoch    2/20 hypo  :tensor([108.0167, 132.1730, 129.0043, 141.1386, 100.7803]) cost : 2406.924316
# Epoch    3/20 hypo  :tensor([127.1730, 155.1978, 151.6908, 165.8436, 118.3425]) cost : 755.009033
# Epoch    4/20 hypo  :tensor([137.8979, 168.0885, 164.3921, 179.6750, 128.1750]) cost : 237.221634
# Epoch    5/20 hypo  :tensor([143.9022, 175.3056, 171.5031, 187.4187, 133.6799]) cost : 74.922653
# Epoch    6/20 hypo  :tensor([147.2638, 179.3463, 175.4843, 191.7541, 136.7620]) cost : 24.050392
# Epoch    7/20 hypo  :tensor([149.1458, 181.6086, 177.7132, 194.1813, 138.4877]) cost : 8.104429
# Epoch    8/20 hypo  :tensor([150.1993, 182.8752, 178.9610, 195.5401, 139.4538]) cost : 3.106273
# Epoch    9/20 hypo  :tensor([150.7891, 183.5843, 179.6596, 196.3009, 139.9948]) cost : 1.539488
# Epoch   10/20 hypo  :tensor([151.1192, 183.9814, 180.0508, 196.7268, 140.2978]) cost : 1.048280
# Epoch   11/20 hypo  :tensor([151.3040, 184.2038, 180.2697, 196.9652, 140.4675]) cost : 0.894254
# Epoch   12/20 hypo  :tensor([151.4074, 184.3283, 180.3923, 197.0986, 140.5626]) cost : 0.845883
# Epoch   13/20 hypo  :tensor([151.4652, 184.3981, 180.4609, 197.1733, 140.6159]) cost : 0.830640
# Epoch   14/20 hypo  :tensor([151.4975, 184.4372, 180.4992, 197.2151, 140.6458]) cost : 0.825765
# Epoch   15/20 hypo  :tensor([151.5155, 184.4592, 180.5207, 197.2385, 140.6626]) cost : 0.824151
# Epoch   16/20 hypo  :tensor([151.5255, 184.4715, 180.5327, 197.2515, 140.6721]) cost : 0.823562
# Epoch   17/20 hypo  :tensor([151.5310, 184.4785, 180.5394, 197.2588, 140.6775]) cost : 0.823300
# Epoch   18/20 hypo  :tensor([151.5341, 184.4824, 180.5432, 197.2628, 140.6806]) cost : 0.823118
# Epoch   19/20 hypo  :tensor([151.5357, 184.4846, 180.5452, 197.2651, 140.6824]) cost : 0.822979
# Epoch   20/20 hypo  :tensor([151.5365, 184.4860, 180.5464, 197.2663, 140.6835]) cost : 0.822851
