# %% [markdown]
# <a href="https://colab.research.google.com/github/9terry-student/PyTorch/blob/main/Linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch.nn.functional as F
import torch.nn as nn
import torch
import torch.optim as optim
from torch.utils.data import DataLoader
from torch.utils.data import Dataset

class MultivariateLinearRegressionModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear = nn.Linear(3, 1)

    def forward(self, x):
        return self.linear(x)

class CustomDataset(Dataset):
  def __init__(self):
    self.x_data=[[73,80,75],[93,88,93],[89,91,90],[96,98,100],[73,66,70]]
    self.y_data=[[152],[185],[180],[196],[142]]

  def __len__(self):
    return len(self.x_data)

  def __getitem__(self,idx):
    x=torch.FloatTensor(self.x_data[idx])
    y=torch.FloatTensor(self.y_data[idx])

    return x,y

dataset=CustomDataset()
dataloader=DataLoader(
    dataset,
    batch_size=2,
    shuffle=True,
)


# 모델 초기화
model=MultivariateLinearRegressionModel()

# optimizer 설정
optimizer=torch.optim.SGD(model.parameters(),lr=2e-5)

nb_epochs=20
for epoch in range(nb_epochs+1):
  for batch_idx,samples in enumerate(dataloader):
    x_train,y_train=samples

    # H(x) 계산
    prediction=model(x_train)

    # cost 계산
    cost=F.mse_loss(prediction,y_train)

    # cost로 H(x) 개선
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()

    print('Epoch {:4d}/{} Batch  {}/{} cost : {:.6f}'.format(
        epoch, nb_epochs,batch_idx+1,len(dataloader),cost.item()))
# Out:
# Epoch    0/20 Batch  1/3 cost : 13430.867188
# Epoch    0/20 Batch  2/3 cost : 57.767021
# Epoch    0/20 Batch  3/3 cost : 0.004518
# Epoch    1/20 Batch  1/3 cost : 3.450993
# Epoch    1/20 Batch  2/3 cost : 0.244047
# Epoch    1/20 Batch  3/3 cost : 0.878792
# Epoch    2/20 Batch  1/3 cost : 1.060167
# Epoch    2/20 Batch  2/3 cost : 0.184679
# Epoch    2/20 Batch  3/3 cost : 2.627351
# Epoch    3/20 Batch  1/3 cost : 3.695035
# Epoch    3/20 Batch  2/3 cost : 1.211540
# Epoch    3/20 Batch  3/3 cost : 0.017879
# Epoch    4/20 Batch  1/3 cost : 1.255643
# Epoch    4/20 Batch  2/3 cost : 0.525585
# Epoch    4/20 Batch  3/3 cost : 0.807738
# Epoch    5/20 Batch  1/3 cost : 0.404608
# Epoch    5/20 Batch  2/3 cost : 1.196268
# Epoch    5/20 Batch  3/3 cost : 0.467342
# Epoch    6/20 Batch  1/3 cost : 0.005442
# Epoch    6/20 Batch  2/3 cost : 1.661427
# Epoch    6/20 Batch  3/3 cost : 0.140911
# Epoch    7/20 Batch  1/3 cost : 0.649421
# Epoch    7/20 Batch  2/3 cost : 0.908360
# ...
