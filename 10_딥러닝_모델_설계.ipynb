# %% [markdown]
# <a href="https://colab.research.google.com/github/9terry-student/PyTorch/blob/main/10_%EB%94%A5%EB%9F%AC%EB%8B%9D_%EB%AA%A8%EB%8D%B8_%EC%84%A4%EA%B3%84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 10장 딥러닝 모델 설계하기

# %% [markdown]
# ### 1. 환경 준비

# %%
# 텐서플로우 라이브러리 안에 있는 케라스 API에서 필요한 함수 호출
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# 데이터를 다루는데 필요한 라이브러리 호출
import numpy as np

# %% [markdown]
# ### 2. 데이터 준비

# %%
# 깃허브에 준비된 데이터 호출
# !git clone https://github.com/taehojo/data.git

# 준비된 수술 환자 데이터 호출
Data_set=np.loadtxt('./data/ThoraricSurgery3.csv',delimiter=',')
X=Data_set[:,0:16]      # 환자의 진찰 기록
y=Data_set[:,16]      # 수술 1년 후 사망/생존 여부
# Out:
# Cloning into 'data'...
# remote: Enumerating objects: 36, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 36 (delta 9), reused 26 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (36/36), 483.12 KiB | 5.25 MiB/s, done.
# Resolving deltas: 100% (9/9), done.

# %% [markdown]
# ### 3. 구조 결정

# %%
# 딥러닝 모델의 구조 결정
model=Sequential()
model.add(Dense(30,input_dim=16,activation='relu'))
model.add(Dense(1,activation='sigmoid'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# ### 4. 모델 실행

# %%
# 딥러닝 모델 실행
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
history=model.fit(X,y,epochs=5,batch_size=16)
# Out:
# Epoch 1/5
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5106 - loss: 1.6427
# Epoch 2/5
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8511 - loss: 0.5450
# Epoch 3/5
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8511 - loss: 0.4804
# Epoch 4/5
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8511 - loss: 0.4741
# Epoch 5/5
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8511 - loss: 0.4687
